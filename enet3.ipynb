# %%
import os
import torch
import torch.nn as nn
import xml.etree.ElementTree as ET
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torchvision.models as models
import torchvision.transforms as transforms
from tqdm import tqdm

# 1. Define paths for ImageNet validation images and annotations
IMAGE_DIR = "/home/kajm20/mnist/ILSVRC/Data/CLS-LOC/val"  
ANNOTATION_DIR = "/home/kajm20/mnist/ILSVRC/Annotations/CLS-LOC/val"  

imagenet_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# 3. Load the synset mapping
synset_mapping_path = "/home/kajm20/mnist/ILSVRC/LOC_synset_mapping.txt"
wordnet_to_imagenet = {}

with open(synset_mapping_path) as f:
    for idx, line in enumerate(f.readlines()):
        wordnet_id, _ = line.split(' ', 1)
        wordnet_to_imagenet[wordnet_id] = idx  

# 4. Define the custom dataset class
class ImageNetValDataset(Dataset):
    def __init__(self, image_dir, annotation_dir, transform=None):
        self.image_dir = image_dir
        self.annotation_dir = annotation_dir
        self.transform = transform
        self.annotation_files = sorted(os.listdir(annotation_dir))

    def __len__(self):
        return len(self.annotation_files)

    def __getitem__(self, idx):
        annotation_path = os.path.join(self.annotation_dir, self.annotation_files[idx])
        tree = ET.parse(annotation_path)
        root = tree.getroot()
        wordnet_id = root.find("object").find("name").text  

        class_idx = wordnet_to_imagenet.get(wordnet_id, -1)  
        image_filename = root.find("filename").text + ".JPEG"
        image_path = os.path.join(self.image_dir, image_filename)

        image = Image.open(image_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        return image, class_idx

num_workers = min(4, os.cpu_count())
# 5. Initialize the dataset and dataloader
imagenet_val_dataset = ImageNetValDataset(IMAGE_DIR, ANNOTATION_DIR, transform=imagenet_transform)
imagenet_val_loader = DataLoader(imagenet_val_dataset, batch_size=32, shuffle=False, num_workers=num_workers)

# 6. Define the model (EfficientNet-B0 with pre-trained weights)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.efficientnet_b0(weights='DEFAULT')  
model.to(device)
model.eval()
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
# Hook function
def hook_fn(module, inputs, output):
    layer_name = f"{module.__class__.__name__} ({id(module)})"
    activation_values[layer_name] = activation_values.get(layer_name, 0) + output.detach().cpu().sum(dim=0)

for name, layer in model.named_modules():
    layer.register_forward_hook(hook_fn)  # Register hook for all layers

# %%
for name, layer in model.named_modules():
    if hasattr(layer, "_forward_hooks"):
        for hook_id in list(layer._forward_hooks.keys()):  # Convert to list to avoid runtime changes
            layer._forward_hooks.pop(hook_id)

# %%
for name, layer in model.named_modules():
    if layer._forward_hooks:
        print(f"Layer: {name}, Hooks: {layer._forward_hooks}")
# Out:
# Layer: , Hooks: OrderedDict({1011: <function hook_fn at 0x7e8e3120c860>})
# Layer: features, Hooks: OrderedDict({1012: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.0, Hooks: OrderedDict({1013: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.0.0, Hooks: OrderedDict({1014: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.0.1, Hooks: OrderedDict({1015: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.0.2, Hooks: OrderedDict({1016: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1, Hooks: OrderedDict({1017: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0, Hooks: OrderedDict({1018: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block, Hooks: OrderedDict({1019: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.0, Hooks: OrderedDict({1020: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.0.0, Hooks: OrderedDict({1021: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.0.1, Hooks: OrderedDict({1022: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.0.2, Hooks: OrderedDict({1023: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.1, Hooks: OrderedDict({1024: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.1.avgpool, Hooks: OrderedDict({1025: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.1.fc1, Hooks: OrderedDict({1026: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.1.fc2, Hooks: OrderedDict({1027: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.1.activation, Hooks: OrderedDict({1028: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.1.scale_activation, Hooks: OrderedDict({1029: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.2, Hooks: OrderedDict({1030: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.2.0, Hooks: OrderedDict({1031: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.block.2.1, Hooks: OrderedDict({1032: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.1.0.stochastic_depth, Hooks: OrderedDict({1033: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2, Hooks: OrderedDict({1034: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0, Hooks: OrderedDict({1035: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block, Hooks: OrderedDict({1036: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.0, Hooks: OrderedDict({1037: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.0.0, Hooks: OrderedDict({1038: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.0.1, Hooks: OrderedDict({1039: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.0.2, Hooks: OrderedDict({1040: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.1, Hooks: OrderedDict({1041: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.1.0, Hooks: OrderedDict({1042: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.1.1, Hooks: OrderedDict({1043: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.1.2, Hooks: OrderedDict({1044: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.2, Hooks: OrderedDict({1045: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.2.avgpool, Hooks: OrderedDict({1046: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.2.fc1, Hooks: OrderedDict({1047: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.2.fc2, Hooks: OrderedDict({1048: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.2.activation, Hooks: OrderedDict({1049: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.2.scale_activation, Hooks: OrderedDict({1050: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.3, Hooks: OrderedDict({1051: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.3.0, Hooks: OrderedDict({1052: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.block.3.1, Hooks: OrderedDict({1053: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.0.stochastic_depth, Hooks: OrderedDict({1054: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1, Hooks: OrderedDict({1055: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block, Hooks: OrderedDict({1056: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.0, Hooks: OrderedDict({1057: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.0.0, Hooks: OrderedDict({1058: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.0.1, Hooks: OrderedDict({1059: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.0.2, Hooks: OrderedDict({1060: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.1, Hooks: OrderedDict({1061: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.1.0, Hooks: OrderedDict({1062: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.1.1, Hooks: OrderedDict({1063: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.1.2, Hooks: OrderedDict({1064: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.2, Hooks: OrderedDict({1065: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.2.avgpool, Hooks: OrderedDict({1066: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.2.fc1, Hooks: OrderedDict({1067: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.2.fc2, Hooks: OrderedDict({1068: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.2.activation, Hooks: OrderedDict({1069: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.2.scale_activation, Hooks: OrderedDict({1070: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.3, Hooks: OrderedDict({1071: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.3.0, Hooks: OrderedDict({1072: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.block.3.1, Hooks: OrderedDict({1073: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.2.1.stochastic_depth, Hooks: OrderedDict({1074: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3, Hooks: OrderedDict({1075: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0, Hooks: OrderedDict({1076: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block, Hooks: OrderedDict({1077: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.0, Hooks: OrderedDict({1078: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.0.0, Hooks: OrderedDict({1079: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.0.1, Hooks: OrderedDict({1080: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.0.2, Hooks: OrderedDict({1081: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.1, Hooks: OrderedDict({1082: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.1.0, Hooks: OrderedDict({1083: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.1.1, Hooks: OrderedDict({1084: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.1.2, Hooks: OrderedDict({1085: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.2, Hooks: OrderedDict({1086: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.2.avgpool, Hooks: OrderedDict({1087: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.2.fc1, Hooks: OrderedDict({1088: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.2.fc2, Hooks: OrderedDict({1089: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.2.activation, Hooks: OrderedDict({1090: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.2.scale_activation, Hooks: OrderedDict({1091: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.3, Hooks: OrderedDict({1092: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.3.0, Hooks: OrderedDict({1093: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.block.3.1, Hooks: OrderedDict({1094: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.0.stochastic_depth, Hooks: OrderedDict({1095: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1, Hooks: OrderedDict({1096: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block, Hooks: OrderedDict({1097: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.0, Hooks: OrderedDict({1098: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.0.0, Hooks: OrderedDict({1099: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.0.1, Hooks: OrderedDict({1100: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.0.2, Hooks: OrderedDict({1101: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.1, Hooks: OrderedDict({1102: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.1.0, Hooks: OrderedDict({1103: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.1.1, Hooks: OrderedDict({1104: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.1.2, Hooks: OrderedDict({1105: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.2, Hooks: OrderedDict({1106: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.2.avgpool, Hooks: OrderedDict({1107: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.2.fc1, Hooks: OrderedDict({1108: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.2.fc2, Hooks: OrderedDict({1109: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.2.activation, Hooks: OrderedDict({1110: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.2.scale_activation, Hooks: OrderedDict({1111: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.3, Hooks: OrderedDict({1112: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.3.0, Hooks: OrderedDict({1113: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.block.3.1, Hooks: OrderedDict({1114: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.3.1.stochastic_depth, Hooks: OrderedDict({1115: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4, Hooks: OrderedDict({1116: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0, Hooks: OrderedDict({1117: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block, Hooks: OrderedDict({1118: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.0, Hooks: OrderedDict({1119: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.0.0, Hooks: OrderedDict({1120: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.0.1, Hooks: OrderedDict({1121: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.0.2, Hooks: OrderedDict({1122: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.1, Hooks: OrderedDict({1123: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.1.0, Hooks: OrderedDict({1124: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.1.1, Hooks: OrderedDict({1125: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.1.2, Hooks: OrderedDict({1126: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.2, Hooks: OrderedDict({1127: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.2.avgpool, Hooks: OrderedDict({1128: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.2.fc1, Hooks: OrderedDict({1129: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.2.fc2, Hooks: OrderedDict({1130: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.2.activation, Hooks: OrderedDict({1131: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.2.scale_activation, Hooks: OrderedDict({1132: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.3, Hooks: OrderedDict({1133: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.3.0, Hooks: OrderedDict({1134: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.block.3.1, Hooks: OrderedDict({1135: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.0.stochastic_depth, Hooks: OrderedDict({1136: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1, Hooks: OrderedDict({1137: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block, Hooks: OrderedDict({1138: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.0, Hooks: OrderedDict({1139: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.0.0, Hooks: OrderedDict({1140: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.0.1, Hooks: OrderedDict({1141: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.0.2, Hooks: OrderedDict({1142: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.1, Hooks: OrderedDict({1143: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.1.0, Hooks: OrderedDict({1144: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.1.1, Hooks: OrderedDict({1145: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.1.2, Hooks: OrderedDict({1146: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.2, Hooks: OrderedDict({1147: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.2.avgpool, Hooks: OrderedDict({1148: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.2.fc1, Hooks: OrderedDict({1149: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.2.fc2, Hooks: OrderedDict({1150: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.2.activation, Hooks: OrderedDict({1151: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.2.scale_activation, Hooks: OrderedDict({1152: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.3, Hooks: OrderedDict({1153: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.3.0, Hooks: OrderedDict({1154: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.block.3.1, Hooks: OrderedDict({1155: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.1.stochastic_depth, Hooks: OrderedDict({1156: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2, Hooks: OrderedDict({1157: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block, Hooks: OrderedDict({1158: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.0, Hooks: OrderedDict({1159: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.0.0, Hooks: OrderedDict({1160: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.0.1, Hooks: OrderedDict({1161: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.0.2, Hooks: OrderedDict({1162: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.1, Hooks: OrderedDict({1163: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.1.0, Hooks: OrderedDict({1164: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.1.1, Hooks: OrderedDict({1165: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.1.2, Hooks: OrderedDict({1166: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.2, Hooks: OrderedDict({1167: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.2.avgpool, Hooks: OrderedDict({1168: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.2.fc1, Hooks: OrderedDict({1169: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.2.fc2, Hooks: OrderedDict({1170: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.2.activation, Hooks: OrderedDict({1171: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.2.scale_activation, Hooks: OrderedDict({1172: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.3, Hooks: OrderedDict({1173: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.3.0, Hooks: OrderedDict({1174: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.block.3.1, Hooks: OrderedDict({1175: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.4.2.stochastic_depth, Hooks: OrderedDict({1176: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5, Hooks: OrderedDict({1177: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0, Hooks: OrderedDict({1178: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block, Hooks: OrderedDict({1179: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.0, Hooks: OrderedDict({1180: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.0.0, Hooks: OrderedDict({1181: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.0.1, Hooks: OrderedDict({1182: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.0.2, Hooks: OrderedDict({1183: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.1, Hooks: OrderedDict({1184: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.1.0, Hooks: OrderedDict({1185: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.1.1, Hooks: OrderedDict({1186: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.1.2, Hooks: OrderedDict({1187: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.2, Hooks: OrderedDict({1188: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.2.avgpool, Hooks: OrderedDict({1189: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.2.fc1, Hooks: OrderedDict({1190: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.2.fc2, Hooks: OrderedDict({1191: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.2.activation, Hooks: OrderedDict({1192: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.2.scale_activation, Hooks: OrderedDict({1193: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.3, Hooks: OrderedDict({1194: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.3.0, Hooks: OrderedDict({1195: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.block.3.1, Hooks: OrderedDict({1196: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.0.stochastic_depth, Hooks: OrderedDict({1197: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1, Hooks: OrderedDict({1198: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block, Hooks: OrderedDict({1199: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.0, Hooks: OrderedDict({1200: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.0.0, Hooks: OrderedDict({1201: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.0.1, Hooks: OrderedDict({1202: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.0.2, Hooks: OrderedDict({1203: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.1, Hooks: OrderedDict({1204: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.1.0, Hooks: OrderedDict({1205: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.1.1, Hooks: OrderedDict({1206: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.1.2, Hooks: OrderedDict({1207: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.2, Hooks: OrderedDict({1208: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.2.avgpool, Hooks: OrderedDict({1209: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.2.fc1, Hooks: OrderedDict({1210: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.2.fc2, Hooks: OrderedDict({1211: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.2.activation, Hooks: OrderedDict({1212: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.2.scale_activation, Hooks: OrderedDict({1213: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.3, Hooks: OrderedDict({1214: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.3.0, Hooks: OrderedDict({1215: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.block.3.1, Hooks: OrderedDict({1216: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.1.stochastic_depth, Hooks: OrderedDict({1217: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2, Hooks: OrderedDict({1218: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block, Hooks: OrderedDict({1219: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.0, Hooks: OrderedDict({1220: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.0.0, Hooks: OrderedDict({1221: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.0.1, Hooks: OrderedDict({1222: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.0.2, Hooks: OrderedDict({1223: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.1, Hooks: OrderedDict({1224: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.1.0, Hooks: OrderedDict({1225: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.1.1, Hooks: OrderedDict({1226: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.1.2, Hooks: OrderedDict({1227: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.2, Hooks: OrderedDict({1228: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.2.avgpool, Hooks: OrderedDict({1229: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.2.fc1, Hooks: OrderedDict({1230: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.2.fc2, Hooks: OrderedDict({1231: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.2.activation, Hooks: OrderedDict({1232: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.2.scale_activation, Hooks: OrderedDict({1233: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.3, Hooks: OrderedDict({1234: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.3.0, Hooks: OrderedDict({1235: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.block.3.1, Hooks: OrderedDict({1236: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.5.2.stochastic_depth, Hooks: OrderedDict({1237: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6, Hooks: OrderedDict({1238: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0, Hooks: OrderedDict({1239: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block, Hooks: OrderedDict({1240: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.0, Hooks: OrderedDict({1241: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.0.0, Hooks: OrderedDict({1242: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.0.1, Hooks: OrderedDict({1243: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.0.2, Hooks: OrderedDict({1244: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.1, Hooks: OrderedDict({1245: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.1.0, Hooks: OrderedDict({1246: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.1.1, Hooks: OrderedDict({1247: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.1.2, Hooks: OrderedDict({1248: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.2, Hooks: OrderedDict({1249: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.2.avgpool, Hooks: OrderedDict({1250: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.2.fc1, Hooks: OrderedDict({1251: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.2.fc2, Hooks: OrderedDict({1252: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.2.activation, Hooks: OrderedDict({1253: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.2.scale_activation, Hooks: OrderedDict({1254: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.3, Hooks: OrderedDict({1255: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.3.0, Hooks: OrderedDict({1256: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.block.3.1, Hooks: OrderedDict({1257: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.0.stochastic_depth, Hooks: OrderedDict({1258: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1, Hooks: OrderedDict({1259: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block, Hooks: OrderedDict({1260: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.0, Hooks: OrderedDict({1261: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.0.0, Hooks: OrderedDict({1262: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.0.1, Hooks: OrderedDict({1263: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.0.2, Hooks: OrderedDict({1264: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.1, Hooks: OrderedDict({1265: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.1.0, Hooks: OrderedDict({1266: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.1.1, Hooks: OrderedDict({1267: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.1.2, Hooks: OrderedDict({1268: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.2, Hooks: OrderedDict({1269: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.2.avgpool, Hooks: OrderedDict({1270: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.2.fc1, Hooks: OrderedDict({1271: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.2.fc2, Hooks: OrderedDict({1272: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.2.activation, Hooks: OrderedDict({1273: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.2.scale_activation, Hooks: OrderedDict({1274: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.3, Hooks: OrderedDict({1275: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.3.0, Hooks: OrderedDict({1276: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.block.3.1, Hooks: OrderedDict({1277: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.1.stochastic_depth, Hooks: OrderedDict({1278: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2, Hooks: OrderedDict({1279: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block, Hooks: OrderedDict({1280: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.0, Hooks: OrderedDict({1281: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.0.0, Hooks: OrderedDict({1282: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.0.1, Hooks: OrderedDict({1283: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.0.2, Hooks: OrderedDict({1284: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.1, Hooks: OrderedDict({1285: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.1.0, Hooks: OrderedDict({1286: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.1.1, Hooks: OrderedDict({1287: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.1.2, Hooks: OrderedDict({1288: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.2, Hooks: OrderedDict({1289: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.2.avgpool, Hooks: OrderedDict({1290: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.2.fc1, Hooks: OrderedDict({1291: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.2.fc2, Hooks: OrderedDict({1292: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.2.activation, Hooks: OrderedDict({1293: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.2.scale_activation, Hooks: OrderedDict({1294: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.3, Hooks: OrderedDict({1295: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.3.0, Hooks: OrderedDict({1296: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.block.3.1, Hooks: OrderedDict({1297: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.2.stochastic_depth, Hooks: OrderedDict({1298: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3, Hooks: OrderedDict({1299: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block, Hooks: OrderedDict({1300: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.0, Hooks: OrderedDict({1301: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.0.0, Hooks: OrderedDict({1302: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.0.1, Hooks: OrderedDict({1303: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.0.2, Hooks: OrderedDict({1304: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.1, Hooks: OrderedDict({1305: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.1.0, Hooks: OrderedDict({1306: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.1.1, Hooks: OrderedDict({1307: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.1.2, Hooks: OrderedDict({1308: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.2, Hooks: OrderedDict({1309: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.2.avgpool, Hooks: OrderedDict({1310: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.2.fc1, Hooks: OrderedDict({1311: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.2.fc2, Hooks: OrderedDict({1312: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.2.activation, Hooks: OrderedDict({1313: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.2.scale_activation, Hooks: OrderedDict({1314: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.3, Hooks: OrderedDict({1315: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.3.0, Hooks: OrderedDict({1316: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.block.3.1, Hooks: OrderedDict({1317: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.6.3.stochastic_depth, Hooks: OrderedDict({1318: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7, Hooks: OrderedDict({1319: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0, Hooks: OrderedDict({1320: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block, Hooks: OrderedDict({1321: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.0, Hooks: OrderedDict({1322: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.0.0, Hooks: OrderedDict({1323: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.0.1, Hooks: OrderedDict({1324: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.0.2, Hooks: OrderedDict({1325: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.1, Hooks: OrderedDict({1326: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.1.0, Hooks: OrderedDict({1327: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.1.1, Hooks: OrderedDict({1328: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.1.2, Hooks: OrderedDict({1329: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.2, Hooks: OrderedDict({1330: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.2.avgpool, Hooks: OrderedDict({1331: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.2.fc1, Hooks: OrderedDict({1332: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.2.fc2, Hooks: OrderedDict({1333: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.2.activation, Hooks: OrderedDict({1334: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.2.scale_activation, Hooks: OrderedDict({1335: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.3, Hooks: OrderedDict({1336: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.3.0, Hooks: OrderedDict({1337: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.block.3.1, Hooks: OrderedDict({1338: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.7.0.stochastic_depth, Hooks: OrderedDict({1339: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.8, Hooks: OrderedDict({1340: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.8.0, Hooks: OrderedDict({1341: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.8.1, Hooks: OrderedDict({1342: <function hook_fn at 0x7e8e3120c860>})
# Layer: features.8.2, Hooks: OrderedDict({1343: <function hook_fn at 0x7e8e3120c860>})
# Layer: avgpool, Hooks: OrderedDict({1344: <function hook_fn at 0x7e8e3120c860>})
# Layer: classifier, Hooks: OrderedDict({1345: <function hook_fn at 0x7e8e3120c860>})
# Layer: classifier.0, Hooks: OrderedDict({1346: <function hook_fn at 0x7e8e3120c860>})
# Layer: classifier.1, Hooks: OrderedDict({1347: <function hook_fn at 0x7e8e3120c860>})

# %%
activation_values = {}  # Stores activation values

# 10. Define the evaluation function
def evaluate_model(model, dataloader):
    correct = 0
    total = 0

    with torch.no_grad():  
        for images, labels in tqdm(dataloader):
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)  

            _, predicted = torch.max(outputs, 1)  
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    accuracy = (correct / total) * 100
    return accuracy

# 11. Evaluate the model on ImageNet validation set
accuracy = evaluate_model(model, imagenet_val_loader)
print(f"EfficientNet-B0 Top-1 Accuracy on ImageNet: {accuracy:.2f}%")
# Out:
#   0%|          | 7/1563 [00:06<24:19,  1.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 22
#      19     return accuracy
#      21 # 11. Evaluate the model on ImageNet validation set
# ---> 22 accuracy = evaluate_model(model, imagenet_val_loader)
#      23 print(f"EfficientNet-B0 Top-1 Accuracy on ImageNet: {accuracy:.2f}%")
#
# Cell In[20], line 12, in evaluate_model(model, dataloader)
#       9 for images, labels in tqdm(dataloader):
#      10     images, labels = images.to(device), labels.to(device)
# ---> 12     outputs = model(images)
#      14     _, predicted = torch.max(outputs, 1)
#      15     correct += (predicted == labels).sum().item()
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1793, in Module._call_impl.<locals>.inner()
#    1790     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1791     args = bw_hook.setup_input_hook(args)
# -> 1793 result = forward_call(*args, **kwargs)
#    1794 if _global_forward_hooks or self._forward_hooks:
#    1795     for hook_id, hook in (
#    1796         *_global_forward_hooks.items(),
#    1797         *self._forward_hooks.items(),
#    1798     ):
#    1799         # mark that always called hook is run
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torchvision/models/efficientnet.py:343, in EfficientNet.forward(self, x)
#     342 def forward(self, x: Tensor) -> Tensor:
# --> 343     return self._forward_impl(x)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torchvision/models/efficientnet.py:333, in EfficientNet._forward_impl(self, x)
#     332 def _forward_impl(self, x: Tensor) -> Tensor:
# --> 333     x = self.features(x)
#     335     x = self.avgpool(x)
#     336     x = torch.flatten(x, 1)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1793, in Module._call_impl.<locals>.inner()
#    1790     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1791     args = bw_hook.setup_input_hook(args)
# -> 1793 result = forward_call(*args, **kwargs)
#    1794 if _global_forward_hooks or self._forward_hooks:
#    1795     for hook_id, hook in (
#    1796         *_global_forward_hooks.items(),
#    1797         *self._forward_hooks.items(),
#    1798     ):
#    1799         # mark that always called hook is run
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1793, in Module._call_impl.<locals>.inner()
#    1790     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1791     args = bw_hook.setup_input_hook(args)
# -> 1793 result = forward_call(*args, **kwargs)
#    1794 if _global_forward_hooks or self._forward_hooks:
#    1795     for hook_id, hook in (
#    1796         *_global_forward_hooks.items(),
#    1797         *self._forward_hooks.items(),
#    1798     ):
#    1799         # mark that always called hook is run
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1793, in Module._call_impl.<locals>.inner()
#    1790     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1791     args = bw_hook.setup_input_hook(args)
# -> 1793 result = forward_call(*args, **kwargs)
#    1794 if _global_forward_hooks or self._forward_hooks:
#    1795     for hook_id, hook in (
#    1796         *_global_forward_hooks.items(),
#    1797         *self._forward_hooks.items(),
#    1798     ):
#    1799         # mark that always called hook is run
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torchvision/models/efficientnet.py:164, in MBConv.forward(self, input)
#     163 def forward(self, input: Tensor) -> Tensor:
# --> 164     result = self.block(input)
#     165     if self.use_res_connect:
#     166         result = self.stochastic_depth(result)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1793, in Module._call_impl.<locals>.inner()
#    1790     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1791     args = bw_hook.setup_input_hook(args)
# -> 1793 result = forward_call(*args, **kwargs)
#    1794 if _global_forward_hooks or self._forward_hooks:
#    1795     for hook_id, hook in (
#    1796         *_global_forward_hooks.items(),
#    1797         *self._forward_hooks.items(),
#    1798     ):
#    1799         # mark that always called hook is run
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1793, in Module._call_impl.<locals>.inner()
#    1790     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1791     args = bw_hook.setup_input_hook(args)
# -> 1793 result = forward_call(*args, **kwargs)
#    1794 if _global_forward_hooks or self._forward_hooks:
#    1795     for hook_id, hook in (
#    1796         *_global_forward_hooks.items(),
#    1797         *self._forward_hooks.items(),
#    1798     ):
#    1799         # mark that always called hook is run
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/module.py:1793, in Module._call_impl.<locals>.inner()
#    1790     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1791     args = bw_hook.setup_input_hook(args)
# -> 1793 result = forward_call(*args, **kwargs)
#    1794 if _global_forward_hooks or self._forward_hooks:
#    1795     for hook_id, hook in (
#    1796         *_global_forward_hooks.items(),
#    1797         *self._forward_hooks.items(),
#    1798     ):
#    1799         # mark that always called hook is run
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/modules/batchnorm.py:193, in _BatchNorm.forward(self, input)
#     186     bn_training = (self.running_mean is None) and (self.running_var is None)
#     188 r"""
#     189 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     190 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     191 used for normalization (i.e. in eval mode when buffers are not None).
#     192 """
# --> 193 return F.batch_norm(
#     194     input,
#     195     # If buffers are not to be tracked, ensure that they won't be updated
#     196     self.running_mean
#     197     if not self.training or self.track_running_stats
#     198     else None,
#     199     self.running_var if not self.training or self.track_running_stats else None,
#     200     self.weight,
#     201     self.bias,
#     202     bn_training,
#     203     exponential_average_factor,
#     204     self.eps,
#     205 )
#
# File ~/miniconda3/envs/mnist/lib/python3.13/site-packages/torch/nn/functional.py:2822, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2819 if training:
#    2820     _verify_batch_size(input.size())
# -> 2822 return torch.batch_norm(
#    2823     input,
#    2824     weight,
#    2825     bias,
#    2826     running_mean,
#    2827     running_var,
#    2828     training,
#    2829     momentum,
#    2830     eps,
#    2831     torch.backends.cudnn.enabled,
#    2832 )
#
# KeyboardInterrupt:

# %%
activation_values
# Out:
# {'Conv2d (139149088319744)': tensor([[[[-6.1614e+04, -6.4736e+04, -6.4768e+04,  ..., -6.4818e+04,
#             -6.4742e+04, -6.4611e+04],
#            [-3.8792e+02, -1.0424e+02, -8.0834e+01,  ..., -1.1180e+02,
#             -7.3723e+01, -8.6023e+01],
#            [-3.4326e+02, -7.1924e+01, -6.5156e+01,  ..., -7.6025e+01,
#             -7.6475e+01, -9.9233e+01],
#            ...,
#            [-3.0130e+02, -1.0557e+02, -1.1884e+02,  ..., -1.1021e+02,
#             -1.6407e+02, -5.1570e+01],
#            [-3.3381e+02, -6.4971e+01, -1.0209e+02,  ...,  1.2123e+01,
#              4.6029e+01, -5.3397e+01],
#            [-2.6913e+02, -5.1732e+01, -1.2867e+01,  ..., -3.0070e+01,
#             -3.6203e+00, -1.5449e+01]],
#
#           [[-8.2052e+04, -1.4913e+03, -1.3505e+03,  ..., -1.3348e+03,
#             -1.4058e+03, -1.3166e+03],
#            [-8.7504e+04,  2.2601e+02,  2.9173e+02,  ...,  3.0114e+02,
#              3.0142e+02,  3.4803e+02],
#            [-8.7628e+04,  3.0711e+02,  2.8056e+02,  ...,  3.3981e+02,
#              3.4002e+02,  2.8244e+02],
#               40323.2148,   49373.9531],
#            [  53077.4102,   40420.7500,   40344.1914,  ...,   40281.8516,
#               40262.8242,   49324.8828],
#            [ -15043.4512,  -18162.8711,  -18183.2617,  ...,  -18164.1445,
#              -18163.7129,  -14916.0078]],
#
#           [[  61769.3672,   62715.3633,   62054.5312,  ...,   62088.4414,
#               62034.7773,    4210.7339],
#            [  58898.2461,   58221.2031,   57681.8008,  ...,   57631.1289,
#               57683.0000,    2127.7725],
#            [  58876.8164,   58027.7617,   57500.4727,  ...,   57527.3242,
#               57507.9062,    2061.7678],
#            ...,
#            [  58841.6953,   58032.9609,   57525.9141,  ...,   57556.6523,
#               57496.5391,    2061.8335],
#            [  58780.0078,   57972.5664,   57508.6172,  ...,   57546.5625,
#               57551.6484,    2070.2937],
#            [  61928.5742,   64371.2734,   63913.8633,  ...,   63901.0898,
#               63862.8047,    6047.9653]],
#
#           [[ -11716.3203,  -13099.5889,  -13715.8076,  ...,  -13917.4922,
#              -13976.8555,   -6445.6016],
#            [ -47279.4727,  -60037.7109,  -61900.7383,  ...,  -61888.2812,
#              -61789.5977,  -46648.7695],
#            [ -53815.6797,  -64211.4531,  -65583.8984,  ...,  -65334.2227,
#              -65542.4297,  -51975.8945],
#            ...,
#            [ -53376.8203,  -63893.6562,  -65331.5352,  ...,  -65292.7344,
#              -65282.8008,  -51562.3203],
#            [ -53589.5664,  -63948.9844,  -65309.0820,  ...,  -65432.3477,
#              -65443.9805,  -51744.8281],
#            [-177221.6250, -188221.0938, -188839.9219,  ..., -188779.2344,
#             -188766.2812, -181058.9844]],
#
#           ...,
#
#           [[ 571905.1250,   53557.0078,   51971.1953,  ...,   51748.7148,
#               51949.8086, -814646.7500],
#            [ 566810.8750,   54077.9844,   53305.1250,  ...,   52998.6523,
#               53157.3750, -883130.8125],
#            [ 565692.7500,   54224.7422,   53410.4492,  ...,   53079.2852,
#               53080.5273, -884929.2500],
#            ...,
#            [ 559346.8125,   54082.1094,   53154.6758,  ...,   52868.1367,
#               53114.4336, -872535.7500],
#            [ 559374.9375,   54213.3281,   53099.1680,  ...,   52801.4609,
#               52981.1328, -872599.4375],
#            [ 419537.2500,   55694.8516,   54924.8125,  ...,   54690.6992,
#               54838.8086, -615721.7500]],
#
#           [[  43080.3906,   45294.6133,   45431.1836,  ...,   45454.9727,
# ...
#            [ -694.9296,   543.0992,  1474.1648,  ...,  1530.7156,
#               597.3243,  -589.5207],
#            [  244.3927,  2104.6389,  3950.8867,  ...,  4441.7915,
#              2478.6238,   398.8885],
#            ...,
#            [  620.6716,  2543.8357,  4268.5283,  ...,  4606.9062,
#              2711.3538,   726.4843],
#            [ -299.3921,   759.2242,  1845.4708,  ...,  2009.3610,
#              1078.8308,   -54.1801],
#            [ -975.9207,  -655.0363,  -182.8739,  ...,   -74.7504,
#              -471.0504,  -782.9855]],
#
#           [[ -758.4116,  1579.7786,  3212.1438,  ...,  3273.2795,
#              1731.3805,  -520.0926],
#            [ 2017.7939,  5412.3496,  8865.5137,  ...,  8740.5342,
#              5602.1426,  2301.1809],
#            [ 3208.9033,  7436.8823, 11873.8408,  ..., 12496.9668,
#              8370.5820,  4030.7441],
#            ...,
#            [ 2397.0063,  5082.9404,  8067.3320,  ...,  8634.3965,
#              5658.9453,  2900.5330],
#            [  467.8884,  1915.4805,  3836.8198,  ...,  3776.7529,
#              2067.6616,   765.0636],
#            [-1069.3627,  -134.0157,   846.0361,  ...,   899.1602,
#                59.3800,  -899.4011]],
#
#           ...,
#
#           [[-2452.2466, -1477.6262,  -916.0270,  ...,  -888.9279,
#             -1315.6609, -2212.4368],
#            [-1035.3353,   330.6124,  1331.1968,  ...,  1454.0243,
#               549.4109,  -772.4334],
#            [ -229.2351,  1323.2600,  2871.6089,  ...,  3106.1753,
#              1640.5933,   -47.6052],
#            ...,
#            [ -758.5528,   507.0105,  1952.7405,  ...,  1902.8116,
#               587.7427,  -643.1648],
#            [-1671.6910,  -803.7533,   121.8439,  ...,   -32.4825,
#              -790.1652, -1472.7443],
#            [-2627.8816, -1957.9012, -1439.6804,  ..., -1408.7030,
#             -1779.4626, -2324.4578]],
#
#           [[ -191.1375,  1427.6289,  2124.9973,  ...,  1999.3650,
#              1327.1166,   165.0010],
#            [  889.6330,  2610.2039,  4616.2461,  ...,  4692.0444,
#              2816.4626,  1325.5344],
#            [  707.6697,  2806.5369,  5329.6353,  ...,  5794.6045,
#              3384.8191,  1185.4313],
#            ...,
#            [ -740.5142,   319.9529,  1429.2153,  ...,  1555.5243,
#               343.7654,  -600.9226],
#            [-1634.7300, -1241.6017,  -745.6745,  ...,  -681.4247,
#             -1089.3303, -1380.7766],
#            [-2008.4912, -1842.8702, -1916.1329,  ..., -1822.8340,
#             -1722.5209, -1773.0128]],
#
#           [[-1721.9639,   191.0278,  2124.3132,  ...,  2137.1084,
#               129.0675, -1764.9045],
#            [ 1181.6750,  5121.5161,  9116.9502,  ...,  9226.2842,
#              5329.8940,  1484.9758],
#            [ 3517.4614,  9455.3438, 14921.4521,  ..., 15000.8379,
#              9816.8887,  4336.1963],
#            ...,
#            [ 1357.1003,  4525.6753,  7550.5913,  ...,  7982.4277,
#              4986.7148,  1824.9434],
#            [ -896.5112,   780.4925,  2588.4592,  ...,  2797.6160,
#              1030.0496,  -554.5227],
#            [-2581.9082, -1690.9296,  -780.7501,  ...,  -591.6804,
#             -1478.3951, -2394.1125]]],
#
#
#          [[[-3032.5903, -2502.6768, -1697.1351,  ..., -1638.3008,
#             -2347.5027, -2863.4653],
#            [-1767.9226,  -663.0790,   892.9887,  ...,   737.5210,
#              -594.6210, -1496.1577],
#            [  173.9908,  1958.3085,  4627.8140,  ...,  4719.2202,
#              2138.7646,   498.5301],
#            ...,
#            [ 2977.8174,  6835.9858, 11328.4092,  ..., 11277.8535,
#              7151.3364,  3595.3630],
#            [ 1117.7836,  4082.3418,  6798.5913,  ...,  6957.6245,
#              4517.5464,  1769.6434],
#            [-1660.7616,   528.2481,  1572.0441,  ...,  1654.5378,
#               771.8204, -1389.0558]],
#
#           [[-1533.6024,  -823.3264,  -563.0430,  ...,  -517.5135,
#              -752.5240, -1367.7638],
#            [ -780.4650,   439.7590,  1436.1465,  ...,  1535.8417,
#               420.3922,  -621.0701],
#            [  371.3078,  2512.6338,  4557.9165,  ...,  4672.2700,
#              2505.5117,   454.3892],
#            ...,
#            [  654.1781,  2542.7229,  4598.0693,  ...,  4957.3975,
#              2797.5972,   792.6501],
#            [ -350.8213,   761.1255,  1813.7078,  ...,  1900.4369,
#              1018.4535,  -128.9108],
#            [ -899.2153,  -583.2903,  -210.9832,  ...,  -286.6244,
#              -496.8581,  -810.4340]],
#
#           [[ -951.9431,  1180.8126,  2726.7915,  ...,  3124.8723,
#              1665.6516,  -552.5078],
#            [ 1658.6459,  5088.6987,  8262.6172,  ...,  8694.4287,
#              5677.0327,  2370.9600],
#            [ 3132.8867,  7286.5420, 11161.6416,  ..., 11883.2988,
#              8112.8057,  4081.1138],
#            ...,
#            [ 2043.0220,  4673.3887,  7637.6333,  ...,  8109.2212,
#              5461.4438,  2878.3337],
#            [  113.3221,  1328.0452,  3203.2188,  ...,  3569.5864,
#              1803.5288,   474.8775],
#            [-1141.8052,  -240.3461,   579.8380,  ...,   673.3085,
#              -110.3494, -1088.1102]],
#
#           ...,
#
#           [[-2461.6318, -1526.2047, -1198.9186,  ..., -1058.9126,
#             -1360.4723, -2255.2144],
#            [-1013.7462,   242.1401,  1069.3430,  ...,  1269.3030,
#               561.1714,  -645.6277],
#            [  -82.5008,  1408.6938,  2886.3596,  ...,  3218.1475,
#              1680.2783,   219.9034],
#            ...,
#            [ -734.8695,   510.2838,  1969.3717,  ...,  2189.2847,
#               852.5816,  -368.9774],
#            [-1850.9927, -1052.0852,  -217.6774,  ...,   -64.5239,
#              -957.8547, -1597.0808],
#            [-2754.7722, -2034.9689, -1610.7577,  ..., -1604.1995,
#             -2056.5608, -2515.7891]],
#
#           [[ -120.8290,  1435.1666,  2010.7201,  ...,  2083.9768,
#              1385.8948,   102.8685],
#            [  916.0630,  2612.6072,  4509.3760,  ...,  4709.4790,
#              2698.1685,  1030.5897],
#            [  562.6367,  2759.3464,  5253.7852,  ...,  5499.4707,
#              3210.9006,  1107.0417],
#            ...,
#            [ -949.1487,    76.5989,  1213.6355,  ...,  1374.9648,
#               304.3314,  -748.1694],
#            [-1780.1091, -1332.5939,  -764.2350,  ...,  -703.0815,
#             -1218.9800, -1606.8419],
#            [-2053.2776, -1914.6572, -1875.4967,  ..., -1807.5388,
#             -1775.4924, -1920.5105]],
#
#           [[-1760.5198,   168.4572,  2111.9663,  ...,  2115.9932,
#               365.5364, -1562.6917],
#            [ 1108.1045,  5039.6724,  9166.4453,  ...,  8882.7998,
#              5183.1396,  1522.7795],
#            [ 3591.3120,  9340.2295, 15020.3701,  ..., 14836.6025,
#              9585.3096,  4013.7722],
#            ...,
#            [ 1420.6578,  4493.0918,  7338.0610,  ...,  7696.3496,
#              4714.7656,  1664.8442],
#            [-1042.1021,   617.5820,  2408.0254,  ...,  2379.7251,
#               727.1893,  -725.9794],
#            [-2622.0874, -1681.6727,  -732.5637,  ...,  -861.0982,
#             -1701.1007, -2383.3113]]]]),
#  'Sequential (139149056744752)': tensor([[[[-3037.2588, -2415.2593, -1531.0776,  ..., -1545.0292,
#             -2461.9863, -2999.4214],
#            [-1689.9653,  -740.4323,   697.8123,  ...,   722.5333,
#              -752.8046, -1683.0679],
#            [  207.6212,  2143.5405,  4489.3081,  ...,  4451.1533,
#              2055.7231,   423.3394],
#            ...,
#            [ 2772.9141,  6611.3096, 10552.1123,  ..., 10669.4238,
#              6799.5386,  3443.7158],
#            [ 1125.2751,  4020.2700,  6566.4951,  ...,  6494.4365,
#              4005.4124,  1471.2567],
#            [-1581.6553,   501.6547,  1608.8092,  ...,  1548.8307,
#               421.0551, -1608.4031]],
#
#           [[-1366.4722,  -608.9531,  -397.6593,  ...,  -402.0261,
#              -604.1458, -1364.2865],
#            [ -694.9296,   543.0992,  1474.1648,  ...,  1530.7156,
#               597.3243,  -589.5207],
#            [  244.3927,  2104.6389,  3950.8867,  ...,  4441.7915,
#              2478.6238,   398.8885],
#            ...,
#            [  620.6716,  2543.8357,  4268.5283,  ...,  4606.9062,
#              2711.3538,   726.4843],
#            [ -299.3921,   759.2242,  1845.4708,  ...,  2009.3610,
#              1078.8308,   -54.1801],
#            [ -975.9207,  -655.0363,  -182.8739,  ...,   -74.7504,
#              -471.0504,  -782.9855]],
#
#           [[ -758.4116,  1579.7786,  3212.1438,  ...,  3273.2795,
#              1731.3805,  -520.0926],
#            [ 2017.7939,  5412.3496,  8865.5137,  ...,  8740.5342,
#              5602.1426,  2301.1809],
#            [ 3208.9033,  7436.8823, 11873.8408,  ..., 12496.9668,
#              8370.5820,  4030.7441],
#            ...,
#            [ 2397.0063,  5082.9404,  8067.3320,  ...,  8634.3965,
#              5658.9453,  2900.5330],
#            [  467.8884,  1915.4805,  3836.8198,  ...,  3776.7529,
#              2067.6616,   765.0636],
#            [-1069.3627,  -134.0157,   846.0361,  ...,   899.1602,
#                59.3800,  -899.4011]],
#
#           ...,
#
#           [[-2452.2466, -1477.6262,  -916.0270,  ...,  -888.9279,
#             -1315.6609, -2212.4368],
#            [-1035.3353,   330.6124,  1331.1968,  ...,  1454.0243,
#               549.4109,  -772.4334],
#            [ -229.2351,  1323.2600,  2871.6089,  ...,  3106.1753,
#              1640.5933,   -47.6052],
#            ...,
#            [ -758.5528,   507.0105,  1952.7405,  ...,  1902.8116,
#               587.7427,  -643.1648],
#            [-1671.6910,  -803.7533,   121.8439,  ...,   -32.4825,
#              -790.1652, -1472.7443],
#            [-2627.8816, -1957.9012, -1439.6804,  ..., -1408.7030,
#             -1779.4626, -2324.4578]],
#
#           [[ -191.1375,  1427.6289,  2124.9973,  ...,  1999.3650,
#              1327.1166,   165.0010],
#            [  889.6330,  2610.2039,  4616.2461,  ...,  4692.0444,
#              2816.4626,  1325.5344],
#            [  707.6697,  2806.5369,  5329.6353,  ...,  5794.6045,
#              3384.8191,  1185.4313],
#            ...,
#            [ -740.5142,   319.9529,  1429.2153,  ...,  1555.5243,
#               343.7654,  -600.9226],
#            [-1634.7300, -1241.6017,  -745.6745,  ...,  -681.4247,
#             -1089.3303, -1380.7766],
#            [-2008.4912, -1842.8702, -1916.1329,  ..., -1822.8340,
#             -1722.5209, -1773.0128]],
#
#           [[-1721.9639,   191.0278,  2124.3132,  ...,  2137.1084,
#               129.0675, -1764.9045],
#            [ 1181.6750,  5121.5161,  9116.9502,  ...,  9226.2842,
#              5329.8940,  1484.9758],
#            [ 3517.4614,  9455.3438, 14921.4521,  ..., 15000.8379,
#              9816.8887,  4336.1963],
#            ...,
#            [ 1357.1003,  4525.6753,  7550.5913,  ...,  7982.4277,
#              4986.7148,  1824.9434],
#            [ -896.5112,   780.4925,  2588.4592,  ...,  2797.6160,
#              1030.0496,  -554.5227],
#            [-2581.9082, -1690.9296,  -780.7501,  ...,  -591.6804,
#             -1478.3951, -2394.1125]]],
#
#
#          [[[-3032.5903, -2502.6768, -1697.1351,  ..., -1638.3008,
#             -2347.5027, -2863.4653],
#            [-1767.9226,  -663.0790,   892.9887,  ...,   737.5210,
#              -594.6210, -1496.1577],
#            [  173.9908,  1958.3085,  4627.8140,  ...,  4719.2202,
#              2138.7646,   498.5301],
#            ...,
#            [ 2977.8174,  6835.9858, 11328.4092,  ..., 11277.8535,
#              7151.3364,  3595.3630],
#            [ 1117.7836,  4082.3418,  6798.5913,  ...,  6957.6245,
#              4517.5464,  1769.6434],
#            [-1660.7616,   528.2481,  1572.0441,  ...,  1654.5378,
#               771.8204, -1389.0558]],
#
#           [[-1533.6024,  -823.3264,  -563.0430,  ...,  -517.5135,
#              -752.5240, -1367.7638],
#            [ -780.4650,   439.7590,  1436.1465,  ...,  1535.8417,
#               420.3922,  -621.0701],
#            [  371.3078,  2512.6338,  4557.9165,  ...,  4672.2700,
#              2505.5117,   454.3892],
#            ...,
#            [  654.1781,  2542.7229,  4598.0693,  ...,  4957.3975,
#              2797.5972,   792.6501],
#            [ -350.8213,   761.1255,  1813.7078,  ...,  1900.4369,
#              1018.4535,  -128.9108],
#            [ -899.2153,  -583.2903,  -210.9832,  ...,  -286.6244,
#              -496.8581,  -810.4340]],
#
#           [[ -951.9431,  1180.8126,  2726.7915,  ...,  3124.8723,
#              1665.6516,  -552.5078],
#            [ 1658.6459,  5088.6987,  8262.6172,  ...,  8694.4287,
#              5677.0327,  2370.9600],
#            [ 3132.8867,  7286.5420, 11161.6416,  ..., 11883.2988,
#              8112.8057,  4081.1138],
#            ...,
#            [ 2043.0220,  4673.3887,  7637.6333,  ...,  8109.2212,
#              5461.4438,  2878.3337],
#            [  113.3221,  1328.0452,  3203.2188,  ...,  3569.5864,
#              1803.5288,   474.8775],
#            [-1141.8052,  -240.3461,   579.8380,  ...,   673.3085,
#              -110.3494, -1088.1102]],
#
#           ...,
#
#           [[-2461.6318, -1526.2047, -1198.9186,  ..., -1058.9126,
#             -1360.4723, -2255.2144],
#            [-1013.7462,   242.1401,  1069.3430,  ...,  1269.3030,
#               561.1714,  -645.6277],
#            [  -82.5008,  1408.6938,  2886.3596,  ...,  3218.1475,
#              1680.2783,   219.9034],
#            ...,
#            [ -734.8695,   510.2838,  1969.3717,  ...,  2189.2847,
#               852.5816,  -368.9774],
#            [-1850.9927, -1052.0852,  -217.6774,  ...,   -64.5239,
#              -957.8547, -1597.0808],
#            [-2754.7722, -2034.9689, -1610.7577,  ..., -1604.1995,
#             -2056.5608, -2515.7891]],
#
#           [[ -120.8290,  1435.1666,  2010.7201,  ...,  2083.9768,
#              1385.8948,   102.8685],
#            [  916.0630,  2612.6072,  4509.3760,  ...,  4709.4790,
#              2698.1685,  1030.5897],
#            [  562.6367,  2759.3464,  5253.7852,  ...,  5499.4707,
#              3210.9006,  1107.0417],
#            ...,
#            [ -949.1487,    76.5989,  1213.6355,  ...,  1374.9648,
#               304.3314,  -748.1694],
#            [-1780.1091, -1332.5939,  -764.2350,  ...,  -703.0815,
#             -1218.9800, -1606.8419],
#            [-2053.2776, -1914.6572, -1875.4967,  ..., -1807.5388,
#             -1775.4924, -1920.5105]],
#
#           [[-1760.5198,   168.4572,  2111.9663,  ...,  2115.9932,
#               365.5364, -1562.6917],
#            [ 1108.1045,  5039.6724,  9166.4453,  ...,  8882.7998,
#              5183.1396,  1522.7795],
#            [ 3591.3120,  9340.2295, 15020.3701,  ..., 14836.6025,
#              9585.3096,  4013.7722],
#            ...,
#            [ 1420.6578,  4493.0918,  7338.0610,  ...,  7696.3496,
#              4714.7656,  1664.8442],
#            [-1042.1021,   617.5820,  2408.0254,  ...,  2379.7251,
#               727.1893,  -725.9794],
#            [-2622.0874, -1681.6727,  -732.5637,  ...,  -861.0982,
#             -1701.1007, -2383.3113]]]]),
#  'AdaptiveAvgPool2d (139149056659520)': tensor([[[[2721.0515]],
#
#           [[1506.9724]],
#
#           [[4926.1851]],
#
#           ...,
#
#           [[ 192.2642]],
#
#           [[1242.3475]],
#
#           [[4566.5488]]],
#
#
#          [[[2885.4304]],
#
#           [[1574.4139]],
#
#           [[4627.3037]],
#
#           ...,
#
#           [[ 182.2490]],
#
#           [[1154.2228]],
#
#           [[4489.0562]]]]),
#  'Dropout (139149088322096)': tensor([[2721.0515, 1506.9724, 4926.1851,  ...,  192.2642, 1242.3475,
#           4566.5488],
#          [2885.4304, 1574.4139, 4627.3037,  ...,  182.2490, 1154.2228,
#           4489.0562]]),
#  'Linear (139149088322432)': tensor([[-8332.5957,  8145.2944, -7897.8369,  ..., -9703.4961, -1033.8323,
#           22331.4609],
#          [-8306.0381,  8220.3350, -8035.2627,  ..., -9510.2979, -1082.8916,
#           22398.9980]]),
#  'Sequential (139149056745872)': tensor([[-8332.5957,  8145.2944, -7897.8369,  ..., -9703.4961, -1033.8323,
#           22331.4609],
#          [-8306.0381,  8220.3350, -8035.2627,  ..., -9510.2979, -1082.8916,
#           22398.9980]]),
#  'EfficientNet (139149088319072)': tensor([[-8332.5957,  8145.2944, -7897.8369,  ..., -9703.4961, -1033.8323,
#           22331.4609],
#          [-8306.0381,  8220.3350, -8035.2627,  ..., -9510.2979, -1082.8916,
#           22398.9980]])}
